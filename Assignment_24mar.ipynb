# %% [markdown]
# ## Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.

# %% [markdown]
# The wine quality data set contains information on various chemical properties of red and white wines, as well as their quality ratings as determined by sensory analysis. The key features of this data set are:
# Fixed acidity: The amount of acid in the wine that does not evaporate during the winemaking process. This feature can affect the wine's overall taste and pH levels.
#
# Volatile acidity: The amount of acetic acid in the wine, which can contribute to the wine's overall flavor and aroma.
#
# Citric acid: A weak organic acid that can contribute to the wine's overall taste and pH levels.
#
# Residual sugar: The amount of sugar remaining in the wine after fermentation. This feature can affect the wine's overall sweetness and balance.
#
# Chlorides: The amount of salt in the wine, which can affect the wine's overall taste and balance.
#
# Free sulfur dioxide: The amount of SO2 that is not bound to other molecules in the wine. This feature can affect the wine's overall aroma and antioxidant properties.
#
# Total sulfur dioxide: The total amount of SO2 in the wine. This feature can affect the wine's overall aroma and antioxidant properties.
#
# Density: The density of the wine, which can affect the wine's overall mouthfeel and body.
#
# pH: The pH level of the wine, which can affect the wine's overall taste and balance.
#
# Sulphates: The amount of potassium sulfate in the wine, which can affect the wine's overall taste and aroma.
#
# Alcohol: The percentage of alcohol in the wine, which can affect the wine's overall body and mouthfeel.
#
# Quality: The quality rating of the wine, as determined by sensory analysis.

# %% [markdown]
# ## Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.

# %% [markdown]
# Handling missing data is an important step in the feature engineering process as it can affect the performance and accuracy of machine learning models. In the wine quality dataset, there were no missing values in the provided data, but in general, there are several ways to handle missing data.
#
# The most common imputation techniques are mean imputation, median imputation, mode imputation, and multiple imputation. Mean imputation replaces missing values with the mean of the non-missing values in the same feature column. Median imputation replaces missing values with the median of the non-missing values, and mode imputation replaces missing values with the mode of the non-missing values. Multiple imputation generates several plausible imputations for each missing value, based on the distribution of the non-missing values in the same feature column.
#
# The advantage of mean, median, and mode imputation techniques is that they are straightforward and easy to implement. They can also work well when the amount of missing data is relatively small and the missing data are randomly distributed. However, these techniques do not capture the uncertainty associated with imputed values, and they may result in biased estimates if the data are not missing at random.
#
# Multiple imputation, on the other hand, captures the uncertainty associated with imputed values by generating several plausible imputations for each missing value. This technique can result in more accurate estimates and can handle missing data that are not missing at random. However, it can be computationally expensive and may require more data preprocessing.
#
# In summary, the choice of imputation technique depends on the nature and amount of missing data and the assumptions made about the missing data mechanism. If the amount of missing data is small and missing data are randomly distributed, mean, median or mode imputation may be appropriate. If missing data are not missing at random, multiple imputation may be a better option. It is important to carefully evaluate the advantages and disadvantages of different imputation techniques before making a choice.

# %% [markdown]
# ## Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?

# %% [markdown]
# Study habits: How often and how effectively a student studies can have a significant impact on exam performance.
#
# - Test anxiety: Students who experience high levels of test anxiety may perform poorly on exams.
# - Attendance: Regular attendance can help students stay up-to-date with course material and perform better on exams.
# - Prior knowledge: Students who have a strong foundation in the subject matter are more likely to perform well on exams.
# - Teacher quality: The effectiveness of the teacher and their teaching methods can impact students' understanding and retention of material.
# - learning skills
# - learning infrastructure
#
# To analyze these factors using statistical techniques, one could collect data on each of these variables from a sample of students and then use regression analysis to model the relationship between each factor and exam performance.

# %% [markdown]
# ## Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?

# %% [markdown]
# Feature engineering, in simple terms, is the act of converting raw observations into desired features using statistical or machine learning approaches.
#
# - Data Cleaning: This involves handling missing values, outliers, and removing duplicates from the dataset.
#
# - Feature Selection: This involves selecting the most relevant variables for the model based on domain knowledge, feature importance, and correlation analysis.
#
# - Feature Transformation: This involves transforming variables to improve their representation or make them more suitable for the model. Examples of transformations include scaling, normalization, binning, and encoding.
#
# - Feature Creation: This involves creating new features by combining or transforming existing ones. This can help capture complex relationships between variables and improve model performance.
#
# - Selecting relevant features: In order to select the most relevant features for the model, it is important to understand the problem and the data set
#
# - Handling missing data: Missing data can be handled by removing rows with missing data, or by imputing the missing values. Different imputation techniques can be used, such as mean imputation, median imputation, or using a regression model to predict missing values.
#
# - Normalizing/Scaling data: In order to bring different variables to a similar scale, normalization techniques such as min-max scaling or z-score normalization
#
# - Encoding categorical variables
#
# - Feature transformation
#
# The selection and transformation of variables for a model depend on the specific problem and the data set, and may require experimentation and domain knowledge.

# %% [markdown]
# ## Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distributionof each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# Load the data set
wine_data = pd.read_csv('winequality-red.csv')

# Perform EDA on each feature
for feature in wine_data.columns:
    # Plot the distribution of the feature
    sns.histplot(wine_data[feature], kde=False)
    plt.title(feature)
    plt.show()
    
    # Check for normality using a normal probability plot
    plt.figure()
    stats.probplot(wine_data[feature], plot=plt)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?

# %%
import pandas as pd
from sklearn.decomposition import PCA

# Load the wine quality data set
df = pd.read_csv('winequality-red.csv')

# Split the data into features (X) and target (y)
X = df.drop('quality', axis=1)
y = df['quality']

# Perform PCA with all components
pca = PCA()
pca.fit(X)

# Calculate the explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Identify the minimum number of principal components required to explain 90% of the variance
total_variance_ratio = 0
num_components = 0
for explained_var in explained_variance_ratio:
    total_variance_ratio += explained_var
    num_components += 1
    if total_variance_ratio >= 0.9:
        break
        
print("Minimum number of principal components required to explain 90% of variance:", num_components)
# Out:
# Minimum number of principal components required to explain 90% of variance: 1
