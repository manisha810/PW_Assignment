# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is micro-framework which has very little dependency on external libraries. It is a very light framework and gives us freedom to do whatever we want.

# %% [markdown]
# * advantages of Flask Framework:-
# . The flask is a micro-framework for web development, so developing and maintaining websites is very easy.
# . Routing URLs in Flask is very easy to implement.
# . This framework is very efficient in handling small to midium sized applications

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![hello_world.png.png](attachment:75ee6176-ce34-492a-9a7c-406e224d2cd4.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.
# App routing is used to map the specific URL with the associated function that is intended to perform some task.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def welcome():
    return "<h1>Welcome to ABC Corporation</h1>"


@app.route("/")
def details():
    return "<h1>Company Name: ABC Corporation <br> Location: India  <br> Contact Detail: 999-999-9999</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (2).png](attachment:7e935057-ea75-467c-912b-8ea7f04daddf.png)

# %% [markdown]
# ![Screenshot (3).png](attachment:280d651b-4e10-4c97-a7f5-cd1d877bde17.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
For building URLs in flask, we use the url_for() function.

# %%
from flask import url_for, Flask
appFlask = Flask(__name__)
@appFlask.route('/home')
def home():
    return 'We are in Home Page!'
with appFlask.test_request_context():
    print(url_for('login'))
